# %%
import pandas as pd

# Load the data from CSV files
dim_data = pd.read_csv('dim.csv')
fact_data = pd.read_csv('fact.csv')

# Define the constants for transaction codes
PAYMENT_TYPE_CODE = 'OPTP0028'  # Code for payment transactions
SPENDING_TYPE_CODE = 'OPTP0000'  # Code for spending transactions

# Convert transaction time to datetime object for easier manipulation
fact_data['TXN_TM'] = pd.to_datetime(fact_data['TXN_TM'])

# Sort the transactions by time to ensure the order is correct for subsequent operations
fact_data_sorted = fact_data.sort_values(by='TXN_TM', ignore_index=True)

# Filter out invalid transaction
fact_data_sorted = fact_data_sorted.loc[~fact_data_sorted['TXN_SRC_ID'].isna()]

# Helper function to get the statement period based on a transaction date
def get_statement_period(txn_date):
    # Statement period starts on the 22nd of the previous month and ends on the 21st of the transaction month
    statement_start = txn_date.replace(day=22, hour=00, minute=00, second=00) - pd.DateOffset(months=1)
    statement_end = txn_date.replace(day=21, hour=00, minute=00, second=00)
    return statement_start, statement_end

# Helper function to calculate the due date of payment
def get_payment_due_date(txn_date):
    # Payment due date is the 5th of the month following the transaction month
    due_date = txn_date.replace(day=5, hour=00, minute=00, second=00) + pd.DateOffset(months=1)
    return due_date

fact_data_sorted.loc[fact_data_sorted['TML_WEB_AP_NM'] == SPENDING_TYPE_CODE, "NET_CASH_FLOW_AMT_LCY"] *= -1

# Add a column for the statement period start and end, and the payment due date to the payments dataframe
# payments = fact_data_sorted[fact_data_sorted['TML_WEB_AP_NM'] == PAYMENT_TYPE_CODE].copy()
# fact_data_sorted[['STATEMENT_START', 'STATEMENT_END']] = fact_data_sorted['TXN_TM'].apply(
#     lambda x: pd.Series(get_statement_period(x))
# )
fact_data_sorted['STATEMENT_START'], fact_data_sorted['STATEMENT_END'] = zip(
    *fact_data_sorted['TXN_TM'].apply(get_statement_period)
)
fact_data_sorted['PAYMENT_DUE_DATE'] = fact_data_sorted['TXN_TM'].apply(get_payment_due_date)

# %%
fact_data_sorted[fact_data_sorted['TML_WEB_AP_NM'] == PAYMENT_TYPE_CODE].head(3)
# Out:
#                              CIF hash  \
# 88   815e4858d422f45f27ff703fce8acfed
# 91   73842a366de67e8d76320590e6a6ced8
# 118  0828e14ddfd5dcfe9b2fc7a54eeba5f8
#
#                                          CARD_NBR hash              TXN_TM  \
# 88   af446dd0dce35b7c0d687b32466726c89239b37dd8fcf9... 2022-05-31 21:23:35
# 91   5001c0d5c425bdfdcd5108671045068a43e3012dc4faf7... 2022-06-01 12:54:21
# 118  f0b80252f29a51ae72a1e4a259ca6857824f00e62cc868... 2022-06-06 15:57:12
#
#     TML_WEB_AP_NM                                                DSC  \
# 88       OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 91       OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 118      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
#
#      NET_CASH_FLOW_AMT_LCY   TXN_SRC_ID CARD_CLASSCIFICATION STATEMENT_START  \
# 88               1520565.0  272976284.0                   VC      2022-04-22
# 91               3500000.0  273092292.0                   VC      2022-05-22
# 118               143912.0  274393715.0                   VC      2022-05-22
#
#     STATEMENT_END PAYMENT_DUE_DATE
# 88     2022-05-21       2022-06-05
# 91     2022-06-21       2022-07-05
# 118    2022-06-21       2022-07-05

# %%
# filter type transaction
filtered_data = fact_data_sorted.loc[(fact_data_sorted['TML_WEB_AP_NM'] == PAYMENT_TYPE_CODE) | (fact_data_sorted['TML_WEB_AP_NM'] == SPENDING_TYPE_CODE)]

# %%
filtered_data['ACCUM_BALANCE'] = filtered_data.groupby(['CIF hash', 'CARD_NBR hash', 'STATEMENT_START', 'STATEMENT_END'])['NET_CASH_FLOW_AMT_LCY'].cumsum()
# Out:
# /var/folders/bm/rjz6mnjd41l_qzx3s93p507w0000gn/T/ipykernel_42111/517043666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['ACCUM_BALANCE'] = filtered_data.groupby(['CIF hash', 'CARD_NBR hash', 'STATEMENT_START', 'STATEMENT_END'])['NET_CASH_FLOW_AMT_LCY'].cumsum()

# %%
filtered_data = filtered_data.merge(dim_data, on=['CIF hash', 'CARD_NBR hash'])

# %%
filtered_data.groupby(['CIF hash', 'CARD_NBR hash', 'STATEMENT_START', 'STATEMENT_END']).agg({'TXN_TM': 'max', 'ACCUM_BALANCE': 'max'})
# Out:
#                                                                                                                                TXN_TM  \
# CIF hash                         CARD_NBR hash                                      STATEMENT_START STATEMENT_END
# 0340ab3837f34a1aa87d5b5a8a25a07e 8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0aa... 2022-08-22      2022-09-21    2022-09-27 13:53:45
#                                                                                     2022-10-22      2022-11-21    2022-11-22 11:16:44
#                                                                                     2022-11-22      2022-12-21    2022-12-08 08:06:55
#                                                                                     2022-12-22      2023-01-21    2023-01-03 15:28:38
#                                                                                     2023-01-22      2023-02-21    2023-02-28 11:56:59
# ...                                                                                                                               ...
# fabbc6f82889b39ea2529bcd3134ede2 a8ea8bc7dd239166636d3626765c69e5a056c57b0ffd1e1... 2023-06-22      2023-07-21    2023-07-31 20:27:27
#                                                                                     2023-07-22      2023-08-21    2023-08-08 10:03:16
# fb57dffb7f96a780b33ba00ba0f2d8c3 a466359e5b3742757bbbf27f9e33386f0f0c746fd6bdc8d... 2023-05-22      2023-06-21    2023-06-13 21:11:36
#                                                                                     2023-06-22      2023-07-21    2023-07-31 20:55:31
#                                                                                     2023-07-22      2023-08-21    2023-08-18 20:27:08
#
#                                                                                                                    ACCUM_BALANCE
# CIF hash                         CARD_NBR hash                                      STATEMENT_START STATEMENT_END
# 0340ab3837f34a1aa87d5b5a8a25a07e 8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0aa... 2022-08-22      2022-09-21       -15728000.0
#                                                                                     2022-10-22      2022-11-21        16060000.0
#                                                                                     2022-11-22      2022-12-21          -44000.0
#                                                                                     2022-12-22      2023-01-21        16181000.0
#                                                                                     2023-01-22      2023-02-21        15500000.0
# ...                                                                                                                          ...
# fabbc6f82889b39ea2529bcd3134ede2 a8ea8bc7dd239166636d3626765c69e5a056c57b0ffd1e1... 2023-06-22      2023-07-21         -225000.0
#                                                                                     2023-07-22      2023-08-21         -338800.0
# fb57dffb7f96a780b33ba00ba0f2d8c3 a466359e5b3742757bbbf27f9e33386f0f0c746fd6bdc8d... 2023-05-22      2023-06-21         -725400.0
#                                                                                     2023-06-22      2023-07-21         4256414.0
#                                                                                     2023-07-22      2023-08-21         2503990.0
#
# [941 rows x 2 columns]

# %%
filtered_data[filtered_data['CIF hash']=='0340ab3837f34a1aa87d5b5a8a25a07e']
# Out:
#                               CIF hash  \
# 5462  0340ab3837f34a1aa87d5b5a8a25a07e
# 5463  0340ab3837f34a1aa87d5b5a8a25a07e
# 5464  0340ab3837f34a1aa87d5b5a8a25a07e
# 5465  0340ab3837f34a1aa87d5b5a8a25a07e
# 5466  0340ab3837f34a1aa87d5b5a8a25a07e
# 5467  0340ab3837f34a1aa87d5b5a8a25a07e
# 5468  0340ab3837f34a1aa87d5b5a8a25a07e
# 5469  0340ab3837f34a1aa87d5b5a8a25a07e
# 5470  0340ab3837f34a1aa87d5b5a8a25a07e
# 5471  0340ab3837f34a1aa87d5b5a8a25a07e
# 5472  0340ab3837f34a1aa87d5b5a8a25a07e
# 5473  0340ab3837f34a1aa87d5b5a8a25a07e
# 5474  0340ab3837f34a1aa87d5b5a8a25a07e
# 5475  0340ab3837f34a1aa87d5b5a8a25a07e
# 5476  0340ab3837f34a1aa87d5b5a8a25a07e
# 5477  0340ab3837f34a1aa87d5b5a8a25a07e
# 5478  0340ab3837f34a1aa87d5b5a8a25a07e
# 5479  0340ab3837f34a1aa87d5b5a8a25a07e
# 5480  0340ab3837f34a1aa87d5b5a8a25a07e
# 5481  0340ab3837f34a1aa87d5b5a8a25a07e
# 5482  0340ab3837f34a1aa87d5b5a8a25a07e
# 5483  0340ab3837f34a1aa87d5b5a8a25a07e
# 5484  0340ab3837f34a1aa87d5b5a8a25a07e
# 5485  0340ab3837f34a1aa87d5b5a8a25a07e
# 5486  0340ab3837f34a1aa87d5b5a8a25a07e
# 5487  0340ab3837f34a1aa87d5b5a8a25a07e
# 5488  0340ab3837f34a1aa87d5b5a8a25a07e
# 5489  0340ab3837f34a1aa87d5b5a8a25a07e
# 5490  0340ab3837f34a1aa87d5b5a8a25a07e
# 5491  0340ab3837f34a1aa87d5b5a8a25a07e
#
#                                           CARD_NBR hash              TXN_TM  \
# 5462  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-09-19 21:52:59
# 5463  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-09-21 18:13:42
# 5464  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-09-21 18:13:45
# 5465  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-09-21 18:14:36
# 5466  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-09-27 13:53:45
# 5467  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-04 17:57:35
# 5468  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-04 17:58:46
# 5469  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-11 11:24:05
# 5470  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-18 12:17:13
# 5471  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-19 11:54:08
# 5472  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-19 11:54:09
# 5473  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-19 11:56:06
# 5474  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-19 11:56:07
# 5475  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-22 08:35:29
# 5476  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-11-22 11:16:44
# 5477  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2022-12-08 08:06:55
# 5478  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-01-03 11:21:50
# 5479  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-01-03 11:38:16
# 5480  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-01-03 14:20:38
# 5481  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-01-03 15:28:38
# 5482  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-02-28 11:39:35
# 5483  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-02-28 11:42:59
# 5484  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-02-28 11:46:26
# 5485  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-02-28 11:56:59
# 5486  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-04-04 14:05:47
# 5487  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-04-04 14:08:03
# 5488  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-05-04 15:09:03
# 5489  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-05-04 15:12:00
# 5490  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-06-05 10:17:48
# 5491  8a310933f4b7f835b19a0a8a2ab43ef865e49111d3fb0a... 2023-06-05 12:07:39
#
#      TML_WEB_AP_NM                                                DSC  \
# 5462      OPTP0000                    CTYVIMO*HOKINHDO 0824853333 704
# 5463      OPTP0000                                 Foody 19002042 704
# 5464      OPTP0000                                 Foody 19002042 704
# 5465      OPTP0000                                 Foody 19002042 704
# 5466      OPTP0000                                 Foody 19002042 704
# 5467      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 5468      OPTP0000  TPBANK QPAY 57 LY THUONG KIET HA NOI VNM 704 0...
# 5469      OPTP0000                                 Foody 19002042 704
# 5470      OPTP0000                                 Foody 19002042 704
# 5471      OPTP0000                                 Foody 19002042 704
# 5472      OPTP0000                                 Foody 19002042 704
# 5473      OPTP0000                                 Foody 19002042 704
# 5474      OPTP0000                                 Foody 19002042 704
# 5475      OPTP0000  TKTT MOBILE BANKING 57 LY THUONG KIET, HOAN KI...
# 5476      OPTP0000                                 Foody 19002042 704
# 5477      OPTP0000  TPBANK QPAY 57 LY THUONG KIET HA NOI VNM 704 0...
# 5478      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 5479      OPTP0000                         KHANH LINH MART HA NOI 704
# 5480      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 5481      OPTP0000                              HKD LE NAM HA NOI 704
# 5482      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 5483      OPTP0000                   HKD NGUYEN GUONG TOAI HA NOI 704
# 5484      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 5485      OPTP0000                   HKD NGUYEN GUONG TOAI HA NOI 704
# 5486      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 5487      OPTP0000                      ANH NGU MAT TROI DONG NAI 704
# 5488      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 5489      OPTP0000                              HKD LE NAM HA NOI 704
# 5490      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
# 5491      OPTP0028  TT QUA TPBANK EBANKING 44 LE NGOC HAN HA NOI V...
#
#       NET_CASH_FLOW_AMT_LCY   TXN_SRC_ID CARD_CLASSCIFICATION STATEMENT_START  \
# 5462            -15728000.0  303376660.0                   VC      2022-08-22
# 5463                -1000.0  303934425.0                   VC      2022-08-22
# 5464                -1000.0  303934425.0                   VC      2022-08-22
# 5465               -78000.0  303934767.0                   VC      2022-08-22
# 5466              -253000.0  305578899.0                   VC      2022-08-22
# 5467             16060000.0  316780911.0                   VC      2022-10-22
# 5468            -16000000.0  316781459.0                   VC      2022-10-22
# 5469              -103000.0  318841726.0                   VC      2022-10-22
# 5470              -183000.0  321000870.0                   VC      2022-10-22
# 5471               -57900.0  321311937.0                   VC      2022-10-22
# 5472               -57900.0  321311937.0                   VC      2022-10-22
# 5473               -57900.0  321312490.0                   VC      2022-10-22
# 5474               -57900.0  321312490.0                   VC      2022-10-22
# 5475              -300000.0  322159723.0                   VC      2022-10-22
# 5476               -67000.0  322208980.0                   VC      2022-10-22
# 5477               -44000.0  327196214.0                   VC      2022-11-22
# 5478              1000000.0  335500476.0                   VC      2022-12-22
# 5479              -819000.0  335506667.0                   VC      2022-12-22
# 5480             16000000.0  335555736.0                   VC      2022-12-22
# 5481            -16181000.0  335578617.0                   VC      2022-12-22
# 5482              1500000.0  352462376.0                   VC      2023-01-22
# 5483             -1500000.0  352463610.0                   VC      2023-01-22
# 5484             15500000.0  352464702.0                   VC      2023-01-22
# 5485            -15500000.0  352467758.0                   VC      2023-01-22
# 5486             16995716.0  363653187.0                   VC      2023-03-22
# 5487            -17000000.0  363653881.0                   VC      2023-03-22
# 5488             17000000.0  373199786.0                   VC      2023-04-22
# 5489            -17000000.0  373200793.0                   VC      2023-04-22
# 5490             17510000.0  383451119.0                   VC      2023-05-22
# 5491               220000.0  383497947.0                   VC      2023-05-22
#
#      STATEMENT_END PAYMENT_DUE_DATE  ACCUM_BALANCE  CREDIT_LIMIT
# 5462    2022-09-21       2022-10-05    -15728000.0      17000000
# 5463    2022-09-21       2022-10-05    -15729000.0      17000000
# 5464    2022-09-21       2022-10-05    -15730000.0      17000000
# 5465    2022-09-21       2022-10-05    -15808000.0      17000000
# 5466    2022-09-21       2022-10-05    -16061000.0      17000000
# 5467    2022-11-21       2022-12-05     16060000.0      17000000
# 5468    2022-11-21       2022-12-05        60000.0      17000000
# 5469    2022-11-21       2022-12-05       -43000.0      17000000
# 5470    2022-11-21       2022-12-05      -226000.0      17000000
# 5471    2022-11-21       2022-12-05      -283900.0      17000000
# 5472    2022-11-21       2022-12-05      -341800.0      17000000
# 5473    2022-11-21       2022-12-05      -399700.0      17000000
# 5474    2022-11-21       2022-12-05      -457600.0      17000000
# 5475    2022-11-21       2022-12-05      -757600.0      17000000
# 5476    2022-11-21       2022-12-05      -824600.0      17000000
# 5477    2022-12-21       2023-01-05       -44000.0      17000000
# 5478    2023-01-21       2023-02-05      1000000.0      17000000
# 5479    2023-01-21       2023-02-05       181000.0      17000000
# 5480    2023-01-21       2023-02-05     16181000.0      17000000
# 5481    2023-01-21       2023-02-05            0.0      17000000
# 5482    2023-02-21       2023-03-05      1500000.0      17000000
# 5483    2023-02-21       2023-03-05            0.0      17000000
# 5484    2023-02-21       2023-03-05     15500000.0      17000000
# 5485    2023-02-21       2023-03-05            0.0      17000000
# 5486    2023-04-21       2023-05-05     16995716.0      17000000
# 5487    2023-04-21       2023-05-05        -4284.0      17000000
# 5488    2023-05-21       2023-06-05     17000000.0      17000000
# 5489    2023-05-21       2023-06-05            0.0      17000000
# 5490    2023-06-21       2023-07-05     17510000.0      17000000
# 5491    2023-06-21       2023-07-05     17730000.0      17000000
